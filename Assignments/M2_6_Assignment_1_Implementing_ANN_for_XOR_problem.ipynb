# %% [markdown]
# # Assignment 1: Benchmarking Neural Nets with the XOR Problem

# %% [markdown]
# ### DS 6050 - School of Data Science - University of Virginia
# In this assignment, you will implement your own neural networks to classify non-linear data from the XOR dataset. For deliverables, you must write code in Python/Pytorch and submit **this** Jupyter Notebook file (.ipynb) to earn a total of 80 pts. Note that you must save your Notebook filename under this format: **yourUvaUserId_assignment_1_ann.ipynb**.

# %%
# You might want to use the following packages
import numpy as np
import os
import torch
print(torch.__version__)
import torch.nn.functional as F
import torch.nn as nn

from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from functools import partial

import warnings
warnings.filterwarnings("ignore")
# Out:
# 2.5.1

# %% [markdown]
# ---
# ## 1. THE DATASET AND VISUALIZATION
#
# We will use the non-linear toy data called the XOR dataset. You may use the code snippet below to generate the `train / validate / test` sets. Feel free to change the number of samples, and noise level. To keep the ratio between the sets consistent, please do not change the test_size and random_state parameters.

# %%
def make_xor(n_points):
    centers = np.array([[0,0],[0,1],[1,0],[1,1]])
    labels = np.array([0,1,1,0])
    data = np.array([]).reshape(-1,3)
    for center, label in zip(centers,labels):
        points = np.random.normal(loc=center,scale=0.2,size=(n_points//4,2))
        points_labels = np.hstack((points,label*np.ones(n_points//4).reshape((-1, 1))))
        data = np.vstack((data,points_labels))
    return (data[:,[0,1]],data[:,2])


X, y = make_xor(1000)
y=y.astype(np.int64)
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2, random_state=49)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size= 0.1, random_state=49)
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.Spectral)
# Out:
# (720, 2)
# (200, 2)
# (80, 2)

# %% [markdown]
# ---
# ## 2. TRAIN A SIMPLE ANN FOR CLASSIFICATION TASK
#
# Use the standard libarary of Neural Net on the training data, and then test the classifier on the test data. You will create a simple ANN with 3 layers: an Input Layer, a Hidden Layer and an Output Layer. For each layer, you can specify the number of nodes appropriate for the XOR problem. Also, feel free to tune the network as you see fit. You have to report the accuracy of the network on the validation set.

# %%
# Transform data to tensor 
X_train = torch.tensor(X_train, dtype=torch.float)
X_val = torch.tensor(X_val, dtype=torch.float)
y_train = torch.tensor(y_train)
y_val = torch.tensor(y_val)
X_test = torch.tensor(X_test, dtype=torch.float)
y_test = torch.tensor(y_test)

# %%
class net(nn.Module):

  def __init__(self):

    super().__init__()
    self.linear1 = nn.Linear(2,10) # different number of inputs?
    self.linear2 = nn.Linear(10,2)

  # Forward pass 
  def forward(self, x):

    x = torch.tanh(self.linear1(x)) # relu or tanh
    x = self.linear2(x)
    return x


  # Your code here!
  # TODO: implement a customized module using establised functions from pytorch
  # Loss can be calculated with nn.CrossEntropyLoss()
  # Linear layer could be added to the model with nn.linear()
  # Hyperbolic tangent can be achieved with torch.tanh()
  # Use any optimizer to optimize model parameters
  # An example can be found at: https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html
  pass

model = net()
print(model)
# Out:
# net(
#   (linear1): Linear(in_features=2, out_features=10, bias=True)
#   (linear2): Linear(in_features=10, out_features=2, bias=True)
# )

# %%
# Hyperparamters:
epochs = 500
learning_rate = 1
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate) # stochastic gradient descent 

# Train model: 
def train(model, X_train, y_train, optimizer):
    model.train()
    pred = model(X_train)
    loss = criterion(pred, y_train)
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

# Evaluate model on validation set:
def test(model, X_val, y_val):
    model.eval()
    pred = model(X_val)
    loss = criterion(pred, y_val)
    return loss

for e in range(epochs):
    train(model, X_train, y_train, optimizer)
    loss = test(model, X_val, y_val)
    if (e % 50 == 0):
        print(f"Epoch: {e}, Loss: {loss}")

# better / more efficient way?
# Out:
# Epoch: 0, Loss: 0.75140380859375
# Epoch: 50, Loss: 0.22387930750846863
# Epoch: 100, Loss: 0.08367374539375305
# Epoch: 150, Loss: 0.05371542647480965
# Epoch: 200, Loss: 0.04047141224145889
# Epoch: 250, Loss: 0.033140115439891815
# Epoch: 300, Loss: 0.0285382978618145
# Epoch: 350, Loss: 0.025376999750733376
# Epoch: 400, Loss: 0.023055950179696083
# Epoch: 450, Loss: 0.021267181262373924

# %% [markdown]
# - - -
# ## 3. IMPLEMENTING YOUR OWN SIMPLE NEURAL NETWORK
#
# Now that you see how the standard library ANN performs on the XOR dataset, you will attempt to implement your own version of the neural network. To help you, a template has been created including the backpropagation. Essensially, you will get the backward gradients for free. However, please note that the backprop implementation assume usage of tanh activation for the hidden layer and softmax for the output layer. There are some subtasks which you need to implement in order to get the network to work properly.

# %%
from sklearn.base import BaseEstimator
from sklearn.preprocessing import OneHotEncoder

class MyNeuralNet(BaseEstimator):
    """Your implementation of a simple neural network"""

    def __init__ (self, n0, n1, n2, alpha=0.01):
        """
        @param: n0: Number of nodes in the input layer
        @param: n1: Number of nodes in the hidden layer
        @param: n2: Number of nodes in the output layer
        @param: alpha: The Learning Rate
        """

        # SUBTASK 1: Initialize the parameters to random values.
        np.random.seed(42)

        # Should weights be normal and bias by zero? 
        '''
        self.W1 = torch.randn(n0, n1) # (2,10)
        self.b1 = torch.zeros(n1,1) # (10)
        self.W2 = torch.randn(n1, n2) # (10, 1)
        self.b2 = torch.zeros(n2,1) # (1)
        '''

        self.W1 = np.random.normal(0,1,(n0,n1))
        self.b1 = np.zeros((n1, 1)) # different dim?
        self.W2 = np.random.normal(0,1,(n1,n2))
        self.b2 = np.zeros((n2, 1))

        # Configure the learning rate
        self.alpha = alpha
        # One-hot encoder for labels
        self.encoder = OneHotEncoder(sparse=False)

    def forward_pass(self, X):
        """
        Pass the signal forward through the layers.
        @param: X: feature
        @return: A1: saved value of the output of the hidden layer
        @return: A2: activated return value of the output layer.
        """
        # SUBTASK 2: Implement Forward propagation.
        # Note: that you must implement tanh activation for the hiden layer
        # and softmax for the output layer
        
        '''
        Z1 = torch.matmul(self.W1.T, X) + self.b1 
        A1 = torch.tanh(Z1)
        print("A1 shape ", A1.shape)
        Z2 = torch.matmul(self.W2.T, A1) + self.b2
        A2 = F.softmax(Z2)
        print("A2 shape ", A2.shape)
        '''

        Z1 = np.matmul(self.W1.T, X) + self.b1
        A1 = np.tanh(Z1)
        Z2 = np.matmul(self.W2.T, A1) + self.b2
        A2 = F.softmax(torch.tensor(Z2))

        return A1, A2


    def loss(self, X, y):
        """
        Evaluate the total loss on the dataset
        @param: X: features
        @param: y: labels
        @return: L: the loss value
        """
        # SUBTASK 3: Calculate the loss using Cross-Entropy
        # You will need to return the average loss on the data
        # Hint: Use A2 to calculate the loss

        A1, A2 = self.forward_pass(X)

        # Another Hint: First, you may want to convert the lable y into a one-hot vector
        Y = self.one_hot(y)
        L = F.cross_entropy(A2, torch.from_numpy(Y)) # might need to use nn.CrossEntropyLoss() 
        avg_L = torch.mean(L) # correct way to calculate avg loss? 

        return avg_L

    def backward_pass(self, A1, A2, X, y):
        """
        @param: X: feature
        @param: y: label
        @param: A1: saved value of the output of the hidden layer
        @param: a2: activated return value of the output layer.

        @return: dW1: the loss gradient of W1
        @return: db1: the loss gradient of b1
        @return: dW2: the loss gradient of W2
        @return: db2: the loss gradient of b2
        """

        # You DO NOT CHANGE this function, ...
        # unless you are advanced and want to use different activation function for your forward pass
        # This is an elegant partial derivative of cross entropy with softmax
        # Ref document: https://deepnotes.io/softmax-crossentropy
        # feel free to cross check the calculated gradients with autograd from Pytorch
        # Ref document: https://pytorch.org/tutorials/beginner/blitz/autograd_tutorial.html
        m   = y.shape[0]
        dZ2 = A2.numpy() - self.one_hot(y) # removed T of Y
        dW2 = np.dot(A1.numpy(), dZ2.T)/m # did dZ2.T instead of A1.T
        db2 = np.sum(dZ2, axis=1, keepdims=True)/m
        dZ1 = np.multiply(np.dot(self.W2, dZ2), 1-np.power(A1.numpy(), 2)) # switched W2 and Z2, took off T from W2, need (10, 720)
        dW1 = np.dot(X, dZ1.T)/m # need (2, 10)
        db1 = np.sum(dZ1, axis=1, keepdims=True)/m # wrong dim, need (10, 1)

        return dW1, db1, dW2, db2


    def fit(self, X, y , epochs, X_val, y_val):
        """
        Learns parameters for the neural network and returns the model.

        @param: X: the training feature
        @param: y: the train label
        @param: epochs: Number of passes through the training data for gradient descent
        @param: X_val: the feature of validation set
        @param: y_val: the label of validation set
        """

        # Input checks: X and X_val needs to be in the form of n0 x m
        if (X.shape[0] > X.shape[1]): X = X.T
        if (X_val.shape[0] > X_val.shape[1]): X_val = X_val.T

        # Gradient descent
        for i in range(0, epochs):

            # SUBTASK 4: Compute the forward, backward, and gradient descent parameter update
            # Step 1: Forward pass
            A1, A2 = self.forward_pass(X)

            # Step 2: Backward pass
            dW1, db1, dW2, db2 = self.backward_pass(A1, A2, X, y)

            # Step 3: Gradient Descent
            self.W1 -= self.alpha * dW1
            self.b1 -= self.alpha * db1
            self.W2 -= self.alpha * dW2
            self.b2 -= self.alpha * db2

            # Print the loss and validation accuracy every 10 epochs.
            if i % 10 == 0:
                print("Epoch %i/%i - loss: %f - accuracy: %f - val_loss: %f - val_accuracy: %f"
                      %(i,epochs, self.loss(X, y), self.evaluate(X, y),
                        self.loss(X_val, y_val), self.evaluate(X_val,y_val)))

    def predict(self, X):
        """
        Predict label vector y
        """
        # check X for the form of n0 x m
        if (X.shape[0] > X.shape[1]): X = X.T

        # SUBTASK 5: Implement the prediction process.
        # Hint: It should include a forward pass, and then use the class with higher probability.
        A1, A2 = self.forward_pass(X)
        y_hat = np.argmax(A2.numpy(), axis=0) # get index of highest prob (0 or 1) for each row

        return y_hat


    def evaluate(self, X, y):
        """
        Evaluate the accuracy of the model
        """
        m = y.shape[0]
        y_hat = self.predict(X)
        correct_y = (y_hat == y).int() # changed to tensor instead of .astype(int) for numpy

        return sum(correct_y)/m


    def one_hot(self, y):
        """
        Utility function: Convert a label vector to one-hot vector
        """
        Y = self.encoder.fit_transform(y.reshape(len(y),1)) # numpy
        return Y.T # Transpose to get into same shape 1 x m


    def plot_decision_boundary(self, X, y):
        """
        Utility Function: Plot a decision boundary for visualization purpose.
        If you don't fully understand this function don't worry, it just generates the contour plot below.
        """
        # Set min and max values and give it some padding
        x_min, x_max = X[:,0].min() - .5, X[:,0].max() + .5
        y_min, y_max = X[:,1].min() - .5, X[:,1].max() + .5
        h = 0.01
        # Generate a grid of points with distance h between them
        xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
        # Predict the function value for the whole gid
        data_grid= np.c_[xx.ravel(), yy.ravel()]
        Z = self.predict(data_grid)
        Z = Z.reshape(xx.shape)

        # Plot the contour and training examples
        plt.contourf(xx, yy, Z, cmap=plt.cm.Pastel1)
        plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.Spectral)

# %% [markdown]
# ---
# ## 4. REFLECT ON THE COMPARISON BETWEEN YOUR IMPLEMENTATION TO THE STANDARD LIBRARY
# Now that you have implemented your own Neural Net class, let's use it! Create at least 3 instances of your Neural Net class, each with a different number of nodes in the hiden layer, tune it with the appropriate learning rate and number of iteration. You will test their performance in the Xor dataset and report the test accuracy metrics for each instance of your neural network.
#
# Based on the test accuracy, compare your models with the standard library version.

# %%
# MODEL 1 here
n0 = 2
n1 = 10
n2 = 2
alpha = 0.01
epochs = 500

# Build a model with 3 layers
myModel1 = MyNeuralNet(n0, n1, n2, alpha)
myModel1.fit(X_train, y_train, epochs, X_val, y_val)
print("Accuracy on the test set is ", myModel1.evaluate(X_test, y_test))

# Plot the decision boundary
myModel1.plot_decision_boundary(X_train, y_train)
# Out:
# Epoch 0/500 - loss: 2368.424354 - accuracy: 0.691667 - val_loss: 175.191911 - val_accuracy: 0.712500
# Epoch 10/500 - loss: 2368.397963 - accuracy: 0.704167 - val_loss: 175.167903 - val_accuracy: 0.725000
# Epoch 20/500 - loss: 2368.375784 - accuracy: 0.709722 - val_loss: 175.147346 - val_accuracy: 0.762500
# Epoch 30/500 - loss: 2368.358168 - accuracy: 0.713889 - val_loss: 175.130696 - val_accuracy: 0.787500
# Epoch 40/500 - loss: 2368.344926 - accuracy: 0.716667 - val_loss: 175.117922 - val_accuracy: 0.787500
# Epoch 50/500 - loss: 2368.335531 - accuracy: 0.722222 - val_loss: 175.108649 - val_accuracy: 0.787500
# Epoch 60/500 - loss: 2368.329328 - accuracy: 0.722222 - val_loss: 175.102343 - val_accuracy: 0.800000
# Epoch 70/500 - loss: 2368.325666 - accuracy: 0.726389 - val_loss: 175.098440 - val_accuracy: 0.800000
# Epoch 80/500 - loss: 2368.323955 - accuracy: 0.726389 - val_loss: 175.096412 - val_accuracy: 0.800000
# Epoch 90/500 - loss: 2368.323691 - accuracy: 0.723611 - val_loss: 175.095793 - val_accuracy: 0.800000
# Epoch 100/500 - loss: 2368.324455 - accuracy: 0.722222 - val_loss: 175.096195 - val_accuracy: 0.800000
# Epoch 110/500 - loss: 2368.325910 - accuracy: 0.720833 - val_loss: 175.097301 - val_accuracy: 0.787500
# Epoch 120/500 - loss: 2368.327798 - accuracy: 0.722222 - val_loss: 175.098868 - val_accuracy: 0.787500
# Epoch 130/500 - loss: 2368.329930 - accuracy: 0.720833 - val_loss: 175.100721 - val_accuracy: 0.787500
# Epoch 140/500 - loss: 2368.332183 - accuracy: 0.718056 - val_loss: 175.102742 - val_accuracy: 0.787500
# Epoch 150/500 - loss: 2368.334486 - accuracy: 0.715278 - val_loss: 175.104863 - val_accuracy: 0.787500
# Epoch 160/500 - loss: 2368.336806 - accuracy: 0.715278 - val_loss: 175.107050 - val_accuracy: 0.787500
# Epoch 170/500 - loss: 2368.339136 - accuracy: 0.715278 - val_loss: 175.109294 - val_accuracy: 0.787500
# Epoch 180/500 - loss: 2368.341485 - accuracy: 0.725000 - val_loss: 175.111598 - val_accuracy: 0.762500
# Epoch 190/500 - loss: 2368.343872 - accuracy: 0.727778 - val_loss: 175.113975 - val_accuracy: 0.775000
# Epoch 200/500 - loss: 2368.346317 - accuracy: 0.737500 - val_loss: 175.116439 - val_accuracy: 0.762500
# Epoch 210/500 - loss: 2368.348842 - accuracy: 0.756944 - val_loss: 175.119006 - val_accuracy: 0.762500
# Epoch 220/500 - loss: 2368.351468 - accuracy: 0.772222 - val_loss: 175.121690 - val_accuracy: 0.787500
# Epoch 230/500 - loss: 2368.354215 - accuracy: 0.784722 - val_loss: 175.124505 - val_accuracy: 0.800000
# Epoch 240/500 - loss: 2368.357102 - accuracy: 0.813889 - val_loss: 175.127465 - val_accuracy: 0.775000
# Epoch 250/500 - loss: 2368.360147 - accuracy: 0.830556 - val_loss: 175.130581 - val_accuracy: 0.762500
# Epoch 260/500 - loss: 2368.363365 - accuracy: 0.843056 - val_loss: 175.133864 - val_accuracy: 0.775000
# Epoch 270/500 - loss: 2368.366773 - accuracy: 0.854167 - val_loss: 175.137324 - val_accuracy: 0.775000
# Epoch 280/500 - loss: 2368.370383 - accuracy: 0.855556 - val_loss: 175.140970 - val_accuracy: 0.775000
# Epoch 290/500 - loss: 2368.374207 - accuracy: 0.855556 - val_loss: 175.144807 - val_accuracy: 0.800000
# Epoch 300/500 - loss: 2368.378254 - accuracy: 0.855556 - val_loss: 175.148841 - val_accuracy: 0.800000
# Epoch 310/500 - loss: 2368.382529 - accuracy: 0.848611 - val_loss: 175.153071 - val_accuracy: 0.800000
# Epoch 320/500 - loss: 2368.387033 - accuracy: 0.850000 - val_loss: 175.157495 - val_accuracy: 0.800000
# Epoch 330/500 - loss: 2368.391762 - accuracy: 0.852778 - val_loss: 175.162105 - val_accuracy: 0.787500
# Epoch 340/500 - loss: 2368.396704 - accuracy: 0.851389 - val_loss: 175.166886 - val_accuracy: 0.787500
# Epoch 350/500 - loss: 2368.401842 - accuracy: 0.847222 - val_loss: 175.171820 - val_accuracy: 0.787500
# Epoch 360/500 - loss: 2368.407152 - accuracy: 0.845833 - val_loss: 175.176878 - val_accuracy: 0.787500
# Epoch 370/500 - loss: 2368.412601 - accuracy: 0.848611 - val_loss: 175.182029 - val_accuracy: 0.787500
# Epoch 380/500 - loss: 2368.418150 - accuracy: 0.850000 - val_loss: 175.187234 - val_accuracy: 0.787500
# Epoch 390/500 - loss: 2368.423755 - accuracy: 0.851389 - val_loss: 175.192446 - val_accuracy: 0.775000
# Epoch 400/500 - loss: 2368.429365 - accuracy: 0.852778 - val_loss: 175.197619 - val_accuracy: 0.787500
# Epoch 410/500 - loss: 2368.434928 - accuracy: 0.854167 - val_loss: 175.202702 - val_accuracy: 0.800000
# Epoch 420/500 - loss: 2368.440391 - accuracy: 0.855556 - val_loss: 175.207643 - val_accuracy: 0.800000
# Epoch 430/500 - loss: 2368.445704 - accuracy: 0.858333 - val_loss: 175.212395 - val_accuracy: 0.800000
# Epoch 440/500 - loss: 2368.450819 - accuracy: 0.861111 - val_loss: 175.216914 - val_accuracy: 0.812500
# Epoch 450/500 - loss: 2368.455696 - accuracy: 0.868056 - val_loss: 175.221162 - val_accuracy: 0.812500
# Epoch 460/500 - loss: 2368.460303 - accuracy: 0.872222 - val_loss: 175.225111 - val_accuracy: 0.812500
# Epoch 470/500 - loss: 2368.464617 - accuracy: 0.875000 - val_loss: 175.228743 - val_accuracy: 0.812500
# Epoch 480/500 - loss: 2368.468624 - accuracy: 0.886111 - val_loss: 175.232053 - val_accuracy: 0.825000
# Epoch 490/500 - loss: 2368.472322 - accuracy: 0.893056 - val_loss: 175.235046 - val_accuracy: 0.837500
# Accuracy on the test set is  tensor(0.9300)

# %%
# MODEL 2 here
n0 = 2
n1 = 8
n2 = 2
alpha = 0.001
epochs = 1000

# Build a model with 3 layers
myModel1 = MyNeuralNet(n0, n1, n2, alpha)
myModel1.fit(X_train, y_train, epochs, X_val, y_val)
print("Accuracy on the test set is ", myModel1.evaluate(X_test, y_test))

# Plot the decision boundary
myModel1.plot_decision_boundary(X_train, y_train)
# Out:
# Epoch 0/1000 - loss: 2368.560581 - accuracy: 0.472222 - val_loss: 175.273976 - val_accuracy: 0.537500
# Epoch 10/1000 - loss: 2368.558891 - accuracy: 0.470833 - val_loss: 175.272731 - val_accuracy: 0.537500
# Epoch 20/1000 - loss: 2368.557204 - accuracy: 0.470833 - val_loss: 175.271488 - val_accuracy: 0.537500
# Epoch 30/1000 - loss: 2368.555519 - accuracy: 0.470833 - val_loss: 175.270249 - val_accuracy: 0.537500
# Epoch 40/1000 - loss: 2368.553839 - accuracy: 0.470833 - val_loss: 175.269015 - val_accuracy: 0.537500
# Epoch 50/1000 - loss: 2368.552165 - accuracy: 0.470833 - val_loss: 175.267787 - val_accuracy: 0.537500
# Epoch 60/1000 - loss: 2368.550499 - accuracy: 0.470833 - val_loss: 175.266567 - val_accuracy: 0.537500
# Epoch 70/1000 - loss: 2368.548841 - accuracy: 0.470833 - val_loss: 175.265356 - val_accuracy: 0.537500
# Epoch 80/1000 - loss: 2368.547193 - accuracy: 0.470833 - val_loss: 175.264154 - val_accuracy: 0.537500
# Epoch 90/1000 - loss: 2368.545556 - accuracy: 0.470833 - val_loss: 175.262964 - val_accuracy: 0.537500
# Epoch 100/1000 - loss: 2368.543933 - accuracy: 0.470833 - val_loss: 175.261787 - val_accuracy: 0.537500
# Epoch 110/1000 - loss: 2368.542323 - accuracy: 0.469444 - val_loss: 175.260623 - val_accuracy: 0.537500
# Epoch 120/1000 - loss: 2368.540730 - accuracy: 0.469444 - val_loss: 175.259474 - val_accuracy: 0.537500
# Epoch 130/1000 - loss: 2368.539153 - accuracy: 0.469444 - val_loss: 175.258342 - val_accuracy: 0.537500
# Epoch 140/1000 - loss: 2368.537595 - accuracy: 0.469444 - val_loss: 175.257227 - val_accuracy: 0.537500
# Epoch 150/1000 - loss: 2368.536057 - accuracy: 0.469444 - val_loss: 175.256131 - val_accuracy: 0.537500
# Epoch 160/1000 - loss: 2368.534541 - accuracy: 0.469444 - val_loss: 175.255054 - val_accuracy: 0.537500
# Epoch 170/1000 - loss: 2368.533046 - accuracy: 0.468056 - val_loss: 175.253999 - val_accuracy: 0.537500
# Epoch 180/1000 - loss: 2368.531575 - accuracy: 0.470833 - val_loss: 175.252965 - val_accuracy: 0.537500
# Epoch 190/1000 - loss: 2368.530129 - accuracy: 0.470833 - val_loss: 175.251954 - val_accuracy: 0.537500
# Epoch 200/1000 - loss: 2368.528708 - accuracy: 0.470833 - val_loss: 175.250967 - val_accuracy: 0.537500
# Epoch 210/1000 - loss: 2368.527315 - accuracy: 0.470833 - val_loss: 175.250004 - val_accuracy: 0.537500
# Epoch 220/1000 - loss: 2368.525948 - accuracy: 0.472222 - val_loss: 175.249066 - val_accuracy: 0.537500
# Epoch 230/1000 - loss: 2368.524610 - accuracy: 0.472222 - val_loss: 175.248154 - val_accuracy: 0.537500
# Epoch 240/1000 - loss: 2368.523301 - accuracy: 0.472222 - val_loss: 175.247268 - val_accuracy: 0.537500
# Epoch 250/1000 - loss: 2368.522021 - accuracy: 0.470833 - val_loss: 175.246408 - val_accuracy: 0.537500
# Epoch 260/1000 - loss: 2368.520771 - accuracy: 0.470833 - val_loss: 175.245575 - val_accuracy: 0.537500
# Epoch 270/1000 - loss: 2368.519551 - accuracy: 0.472222 - val_loss: 175.244768 - val_accuracy: 0.537500
# Epoch 280/1000 - loss: 2368.518361 - accuracy: 0.472222 - val_loss: 175.243989 - val_accuracy: 0.525000
# Epoch 290/1000 - loss: 2368.517201 - accuracy: 0.473611 - val_loss: 175.243236 - val_accuracy: 0.525000
# Epoch 300/1000 - loss: 2368.516072 - accuracy: 0.473611 - val_loss: 175.242510 - val_accuracy: 0.525000
# Epoch 310/1000 - loss: 2368.514972 - accuracy: 0.475000 - val_loss: 175.241810 - val_accuracy: 0.525000
# Epoch 320/1000 - loss: 2368.513901 - accuracy: 0.475000 - val_loss: 175.241135 - val_accuracy: 0.525000
# Epoch 330/1000 - loss: 2368.512860 - accuracy: 0.473611 - val_loss: 175.240486 - val_accuracy: 0.525000
# Epoch 340/1000 - loss: 2368.511847 - accuracy: 0.472222 - val_loss: 175.239861 - val_accuracy: 0.525000
# Epoch 350/1000 - loss: 2368.510862 - accuracy: 0.472222 - val_loss: 175.239261 - val_accuracy: 0.525000
# Epoch 360/1000 - loss: 2368.509904 - accuracy: 0.472222 - val_loss: 175.238683 - val_accuracy: 0.525000
# Epoch 370/1000 - loss: 2368.508972 - accuracy: 0.470833 - val_loss: 175.238128 - val_accuracy: 0.525000
# Epoch 380/1000 - loss: 2368.508066 - accuracy: 0.470833 - val_loss: 175.237595 - val_accuracy: 0.525000
# Epoch 390/1000 - loss: 2368.507184 - accuracy: 0.470833 - val_loss: 175.237081 - val_accuracy: 0.525000
# Epoch 400/1000 - loss: 2368.506325 - accuracy: 0.470833 - val_loss: 175.236588 - val_accuracy: 0.525000
# Epoch 410/1000 - loss: 2368.505488 - accuracy: 0.470833 - val_loss: 175.236112 - val_accuracy: 0.525000
# Epoch 420/1000 - loss: 2368.504672 - accuracy: 0.470833 - val_loss: 175.235654 - val_accuracy: 0.525000
# Epoch 430/1000 - loss: 2368.503877 - accuracy: 0.470833 - val_loss: 175.235213 - val_accuracy: 0.525000
# Epoch 440/1000 - loss: 2368.503100 - accuracy: 0.473611 - val_loss: 175.234786 - val_accuracy: 0.525000
# Epoch 450/1000 - loss: 2368.502340 - accuracy: 0.473611 - val_loss: 175.234374 - val_accuracy: 0.525000
# Epoch 460/1000 - loss: 2368.501597 - accuracy: 0.473611 - val_loss: 175.233974 - val_accuracy: 0.525000
# Epoch 470/1000 - loss: 2368.500870 - accuracy: 0.473611 - val_loss: 175.233586 - val_accuracy: 0.525000
# Epoch 480/1000 - loss: 2368.500156 - accuracy: 0.476389 - val_loss: 175.233209 - val_accuracy: 0.525000
# Epoch 490/1000 - loss: 2368.499455 - accuracy: 0.477778 - val_loss: 175.232842 - val_accuracy: 0.525000
# Epoch 500/1000 - loss: 2368.498766 - accuracy: 0.479167 - val_loss: 175.232483 - val_accuracy: 0.525000
# Epoch 510/1000 - loss: 2368.498087 - accuracy: 0.483333 - val_loss: 175.232131 - val_accuracy: 0.525000
# Epoch 520/1000 - loss: 2368.497418 - accuracy: 0.484722 - val_loss: 175.231786 - val_accuracy: 0.525000
# Epoch 530/1000 - loss: 2368.496757 - accuracy: 0.487500 - val_loss: 175.231446 - val_accuracy: 0.525000
# Epoch 540/1000 - loss: 2368.496103 - accuracy: 0.488889 - val_loss: 175.231111 - val_accuracy: 0.525000
# Epoch 550/1000 - loss: 2368.495455 - accuracy: 0.490278 - val_loss: 175.230779 - val_accuracy: 0.525000
# Epoch 560/1000 - loss: 2368.494813 - accuracy: 0.490278 - val_loss: 175.230450 - val_accuracy: 0.537500
# Epoch 570/1000 - loss: 2368.494175 - accuracy: 0.493056 - val_loss: 175.230123 - val_accuracy: 0.537500
# Epoch 580/1000 - loss: 2368.493539 - accuracy: 0.495833 - val_loss: 175.229796 - val_accuracy: 0.537500
# Epoch 590/1000 - loss: 2368.492907 - accuracy: 0.498611 - val_loss: 175.229470 - val_accuracy: 0.537500
# Epoch 600/1000 - loss: 2368.492275 - accuracy: 0.500000 - val_loss: 175.229142 - val_accuracy: 0.537500
# Epoch 610/1000 - loss: 2368.491645 - accuracy: 0.501389 - val_loss: 175.228814 - val_accuracy: 0.537500
# Epoch 620/1000 - loss: 2368.491014 - accuracy: 0.505556 - val_loss: 175.228483 - val_accuracy: 0.537500
# Epoch 630/1000 - loss: 2368.490382 - accuracy: 0.506944 - val_loss: 175.228149 - val_accuracy: 0.537500
# Epoch 640/1000 - loss: 2368.489748 - accuracy: 0.513889 - val_loss: 175.227811 - val_accuracy: 0.550000
# Epoch 650/1000 - loss: 2368.489112 - accuracy: 0.519444 - val_loss: 175.227470 - val_accuracy: 0.562500
# Epoch 660/1000 - loss: 2368.488473 - accuracy: 0.523611 - val_loss: 175.227124 - val_accuracy: 0.562500
# Epoch 670/1000 - loss: 2368.487831 - accuracy: 0.529167 - val_loss: 175.226772 - val_accuracy: 0.562500
# Epoch 680/1000 - loss: 2368.487184 - accuracy: 0.540278 - val_loss: 175.226416 - val_accuracy: 0.562500
# Epoch 690/1000 - loss: 2368.486533 - accuracy: 0.544444 - val_loss: 175.226053 - val_accuracy: 0.562500
# Epoch 700/1000 - loss: 2368.485877 - accuracy: 0.547222 - val_loss: 175.225683 - val_accuracy: 0.575000
# Epoch 710/1000 - loss: 2368.485215 - accuracy: 0.559722 - val_loss: 175.225307 - val_accuracy: 0.587500
# Epoch 720/1000 - loss: 2368.484546 - accuracy: 0.577778 - val_loss: 175.224923 - val_accuracy: 0.612500
# Epoch 730/1000 - loss: 2368.483872 - accuracy: 0.594444 - val_loss: 175.224532 - val_accuracy: 0.662500
# Epoch 740/1000 - loss: 2368.483191 - accuracy: 0.598611 - val_loss: 175.224133 - val_accuracy: 0.662500
# Epoch 750/1000 - loss: 2368.482503 - accuracy: 0.608333 - val_loss: 175.223726 - val_accuracy: 0.675000
# Epoch 760/1000 - loss: 2368.481808 - accuracy: 0.627778 - val_loss: 175.223310 - val_accuracy: 0.700000
# Epoch 770/1000 - loss: 2368.481105 - accuracy: 0.647222 - val_loss: 175.222887 - val_accuracy: 0.725000
# Epoch 780/1000 - loss: 2368.480394 - accuracy: 0.659722 - val_loss: 175.222454 - val_accuracy: 0.725000
# Epoch 790/1000 - loss: 2368.479676 - accuracy: 0.666667 - val_loss: 175.222013 - val_accuracy: 0.725000
# Epoch 800/1000 - loss: 2368.478950 - accuracy: 0.680556 - val_loss: 175.221564 - val_accuracy: 0.725000
# Epoch 810/1000 - loss: 2368.478216 - accuracy: 0.688889 - val_loss: 175.221105 - val_accuracy: 0.750000
# Epoch 820/1000 - loss: 2368.477473 - accuracy: 0.688889 - val_loss: 175.220638 - val_accuracy: 0.750000
# Epoch 830/1000 - loss: 2368.476723 - accuracy: 0.693056 - val_loss: 175.220162 - val_accuracy: 0.762500
# Epoch 840/1000 - loss: 2368.475965 - accuracy: 0.694444 - val_loss: 175.219678 - val_accuracy: 0.762500
# Epoch 850/1000 - loss: 2368.475199 - accuracy: 0.697222 - val_loss: 175.219185 - val_accuracy: 0.762500
# Epoch 860/1000 - loss: 2368.474425 - accuracy: 0.695833 - val_loss: 175.218683 - val_accuracy: 0.762500
# Epoch 870/1000 - loss: 2368.473643 - accuracy: 0.697222 - val_loss: 175.218173 - val_accuracy: 0.737500
# Epoch 880/1000 - loss: 2368.472854 - accuracy: 0.698611 - val_loss: 175.217655 - val_accuracy: 0.750000
# Epoch 890/1000 - loss: 2368.472058 - accuracy: 0.701389 - val_loss: 175.217129 - val_accuracy: 0.750000
# Epoch 900/1000 - loss: 2368.471254 - accuracy: 0.701389 - val_loss: 175.216595 - val_accuracy: 0.750000
# Epoch 910/1000 - loss: 2368.470443 - accuracy: 0.702778 - val_loss: 175.216054 - val_accuracy: 0.750000
# Epoch 920/1000 - loss: 2368.469626 - accuracy: 0.705556 - val_loss: 175.215505 - val_accuracy: 0.750000
# Epoch 930/1000 - loss: 2368.468802 - accuracy: 0.706944 - val_loss: 175.214950 - val_accuracy: 0.750000
# Epoch 940/1000 - loss: 2368.467973 - accuracy: 0.708333 - val_loss: 175.214388 - val_accuracy: 0.750000
# Epoch 950/1000 - loss: 2368.467137 - accuracy: 0.709722 - val_loss: 175.213819 - val_accuracy: 0.750000
# Epoch 960/1000 - loss: 2368.466296 - accuracy: 0.708333 - val_loss: 175.213245 - val_accuracy: 0.750000
# Epoch 970/1000 - loss: 2368.465451 - accuracy: 0.708333 - val_loss: 175.212665 - val_accuracy: 0.750000
# Epoch 980/1000 - loss: 2368.464601 - accuracy: 0.708333 - val_loss: 175.212080 - val_accuracy: 0.750000
# Epoch 990/1000 - loss: 2368.463746 - accuracy: 0.705556 - val_loss: 175.211489 - val_accuracy: 0.750000
# Accuracy on the test set is  tensor(0.7400)

# %%
# MODEL 3 here

# %%
# COMPARISONS OF THESE MODELS WITH THE STANDARD LIBRARY MODEL IN TASK 2

# %% [markdown]
# ## Reflection
# Write at least a paragraph answering these prompts: How did your own network perform? Is there any major differences between the implementations? Finally, reflecting on your experience implementing a learning algorithm for this assignment (Was it hard/easy/fun?, From which part did you learn the most?)!

# %% [markdown]
# ---
# # Get Help?
# In case you get stuck in any step in the process, you may find some useful information from:
#
#  * Consult my lecture slides on Module 2.
#  * Post a question in Piazza.
#  * Talk to the TA, they are available and there to help you during office hour.
#  * Come talk to me or email me <vga8uf@virginia.edu> with subject starting "DS 6050 Assignment 1:...".
#
# Part of the codes used in this assignment is modified from Konstantinos Kitsios under the 3-Clause BSD License. Best of luck and have fun!
